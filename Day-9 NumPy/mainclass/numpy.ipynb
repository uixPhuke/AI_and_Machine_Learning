# %% [markdown]
# # NumPy

# %%
#installation
## !pip3 install numpy

import numpy as np

# %%
arr=np.array([1,3,5,7,9])
print(arr,type(arr))
# Out:
# [1 3 5 7 9] <class 'numpy.ndarray'>

# %% [markdown]
# ## Numply arrays are Faster (Optimized in C)

# %%
#execution performance
import time
size=10_000_000

#python list
py_list=list(range(size))
start=time.time()
sq_list=[x**2 for x in py_list]
end=time.time()
print(f"Python List time = {end-start} seconds")


#numpy arrays
np_arr=np.array(py_list)
start=time.time()
sq_list=np_arr ** 2
end=time.time()
print(f"Numpy Arrays time = {end-start} seconds")
# Out:
# Python List time = 0.4103269577026367 seconds
# Numpy Arrays time = 0.07918787002563477 seconds

# %% [markdown]
# ## Memory

# %%
import sys

print(f"python list size = {sys.getsizeof(py_list) * len(py_list)} bytes")

print(f"Numpy array size = {np_arr.nbytes} bytes")
# Out:
# python list size = 800000560000000 bytes
# Numpy array size = 80000000 bytes
